# %% [markdown]
# **Vou dividir este notebook em duas partes: a primeira é um chatbot que responderá apenas perguntas gerais; a segunda é um chatbot que lerá uma URL de um local específico que você indicar e responderá suas dúvidas sobre isso.**

# %% [markdown]
# Obs: Usei a biblioteca LangChain para construir estes ChatBots e usei uma API da groq para acessar o modelo de linguagem llama3

# %% [markdown]
# #Parte 1:

# %%
# !pip install langchain==0.3.0
# !pip install langchain-groq==0.2.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 15.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.4
#     Uninstalling langchain-0.3.4:
#       Successfully uninstalled langchain-0.3.4
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 kB 8.8 MB/s eta 0:00:00
# ...

# %%
import os
from langchain_groq import ChatGroq
from langchain.prompts import ChatPromptTemplate

api_key = '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'
os.environ['GROQ_API_KEY'] = api_key

chat = ChatGroq(model='llama-3.1-70b-versatile')


def resposta_do_bot(lista_mensagens):
  template = ChatPromptTemplate.from_messages(
      [('system', 'Você é um assistente amigável chamado Fábio')] +
      lista_mensagens
  )
  chain = template | chat
  return chain.invoke({}).content

print('Bem-vindo ao melhor ChatBot do Brasil! (Digite x se você quiser sair!)\n')
mensagens = []
while True:
  pergunta = input('Usuário: ')
  if pergunta.lower() == 'x':
    break
  mensagens.append(('user', pergunta))
  resposta = resposta_do_bot(mensagens)
  mensagens.append(('assistant', resposta))
  print(f'Bot: {resposta}')

print('\nMuito obrigado por utilizar o FabioBot!')
# Out:
# Bem-vindo ao melhor ChatBot do Brasil! (Digite x se você quiser sair!)
#
# Usuário: Olá
# Bot: Olá! Estou aqui para ajudar com qualquer coisa que você precise. Como posso te ajudar hoje?
# Usuário: Você pode me dizer quem foi john law?
# Bot: John Law! Ele foi um economista, matemático e banqueiro escocês do século XVIII. Nascido em 1671 em Edimburgo, Escócia, Law é conhecido por ter sido um dos principais proponentes da teoria do dinheiro fiduciário e por ter desempenhado um papel importante na história financeira da França.
#
# Law é mais famoso por ter criado o sistema de papel-moeda na França, que foi implementado em 1716. Ele convenceu o regente francês, Filipe II, Duque de Orléans, a criar um banco estatal que emitisse papel-moeda, conhecido como "assignats". Essa medida visava estimular a economia francesa, que estava em crise após a morte de Luís XIV.
#
# ...

# %% [markdown]
# #Parte 2:

# %%
# !pip install langchain==0.3.0
# !pip install langchain-groq==0.2.0
# !pip install langchain-community==0.3.0
# !pip install youtube_transcript_api==0.6.2
# !pip install pypdf==5.0.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 35.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 13.5 MB/s eta 0:00:00
# ...

# %%
import os
from langchain_groq import ChatGroq
from langchain.prompts import ChatPromptTemplate


api_key = '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'
os.environ['GROQ API KEY'] = api_key

chat = ChatGroq(api_key = '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', model = 'llama-3.1-70b-versatile')


def resposta_bot(mensagens, documentos):
  mensagem_system = '''
  Você é um assistente amigável chamado Fabio
  Você utiliza as seguintes informações para formular as suas respostas: {informacoes}
  '''
  mensagens_modelo =  [('system', mensagem_system)]
  mensagens_modelo += mensagens
  template = ChatPromptTemplate.from_messages(mensagens_modelo)
  chain = template | chat
  return chain.invoke({'informacoes': documento}).content

# %%
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.document_loaders import YoutubeLoader
from langchain_community.document_loaders import PyPDFLoader


def carrega_site():
  url_site = input('Digite a url do site: ')
  loader = WebBaseLoader(url_site) #Passar o url do site que quer fazer o scraping que é extração dos dados
  lista_documentos = loader.load()
  documento = ''
  for doc in lista_documentos:
    documento += doc.page_content
  return documento

def carrega_youtube():
  url_youtube = input('Digite a url do vídeo: ')
  loader = YoutubeLoader.from_youtube_url(url_youtube, language=['pt'])
  lista_documentos = loader.load()
  documento = ''
  for doc in lista_documentos:
    documento += doc.page_content
  return documento

# %%
print('Bem-Vindo ao melhor ChatBot do Brasil')

texto_selecao = '''
Digite 1 se você quiser conversar com um site
Digite 2 se você quiser conversar com um vídeo de youtube
'''

while True:
  selecao = input(texto_selecao) #O que foi digitado será lido sempre em String
  if selecao == '1':
    documento = carrega_site()
    break
  elif selecao == '2':
    documento = carrega_youtube()
    break
  else:
    print('Coloque um número válido!')


mensagens = []
while True:
  pergunta = input('Usuário: ')
  if pergunta.lower() == 'x':
    break
  mensagens.append(('user', pergunta))
  resposta = resposta_bot(mensagens, documento)
  mensagens.append(('assistant', pergunta))
  print(f'Bot: {resposta}')

print('Obrigado Por Usar')
print(f'\n{mensagens}')
# Out:
# Bem-Vindo ao melhor ChatBot do Brasil
#
# Digite 1 se você quiser conversar com um site
# Digite 2 se você quiser conversar com um vídeo de youtube
# 1
# Digite a url do site: https://www.youtube.com/
# Usuário: este é o site do youtube?
# Bot: Sim, parece que sim! As informações que você forneceu parecem ser da página de ajuda ou termos de uso do YouTube, uma plataforma de compartilhamento de vídeos online. É lá que eu, Fabio, estou para ajudar com qualquer dúvida ou pergunta que você tenha! Como posso ajudar você hoje?
# Usuário: Quais botões tem nesse site?
# Bot: Estou vendo... Nesse site do YouTube, há alguns botões e opções principais, tais como:
#
# * About (Sobre)
# * Press (Imprensa)
# * Copyright (Direitos Autorais)
# * Contact us (Contate-nos)
# * Creators (Criadores)
# * Advertise (Anunciar)
# * Developers (Desenvolvedores)
# * Terms (Termos de Serviço)
# * Privacy Policy (Política de Privacidade)
# * Safety (Segurança)
#
# ...
